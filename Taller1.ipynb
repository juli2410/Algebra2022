# %% [markdown]
# # Taller
#
# 1. Sea $A$ una matriz simétrica de $n\times n$ y definida positiva, e.d.  que para todo  $x\in  \mathbb{R}^n$  no nulo se tiene $$x^TAx>0.$$ Demostrar que con $A$ podemos definir un producto interno de $\mathbb{R}^n$ como
# $$x^TAy=<y,x>$$
#
# 2.
#
# a.  Implementar el algoritmo gram schmidt para encontrar la factorización $QR$ de una matriz dada.
#
#
#   b. Sea la matria $A$ \begin{bmatrix}
# 4& 1 & &\\
# 1& 4 &1 &\\
# & 1 &4 &1\\
# &  & 1&4\end{bmatrix}
# Demuestre que $A$ es definida positiva simetrica e implemente el algoritmo de GS para obtener la factorización $QR$ con la defición de este producto punto para $\mathbb{R}^4$
#
# 4. Sea el siguiente conjunto de vectores
# $$B=\left\{x_1=\begin{pmatrix}1\\-1\\0\\1\end{pmatrix}\ ,
# x_2=\begin{pmatrix}1\\1\\0\\1\end{pmatrix}\ ,
# x_3=\begin{pmatrix}0\\-1\\-1\\2\end{pmatrix}\right\}$$
#
#   a. Muestre que los elementos de $B$ son Linealmente independientes
#
#   b. Usando el algoritmo Gram -Schmidt construya una base ortonormal desde $B$
#
#
# 5. Realice la gráfica del de una bola en $\mathbb{R}^2$  con las normas $$||{\bf x}||=max(x_i),$$
# $$||{\bf x}||=(|x_1|^p+|x_2|^p)^{\frac{1}{p}}$$
#
#
#
#
#
#
#
#
#
# 6. Sea el siguiente conjunto de vectores
# $$B=\left\{u_1=\frac{1}{\sqrt{2}}\begin{pmatrix}1\\-1\\0\end{pmatrix}\ ,
# u_2=\frac{1}{\sqrt{3}}\begin{pmatrix}1\\1\\1\end{pmatrix}\ ,
# u_3=\frac{1}{\sqrt{6}}\begin{pmatrix}-1\\-1\\2\end{pmatrix}
# \right\}$$
#
#
#   a. Muestre que $B$ es una base de $\mathbb{R}^3$ con el producto usal
#
#    b. Exprese $\begin{pmatrix}-1\\2\\1
# \end{pmatrix}$ como combinación lineal de elementos de $B$

# %% [markdown]
# 6. Busque que significa el algoitmo de k-mean y para que se usa.
#
# 7. Lea tatentamente el siguiente código y comente cada línea

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns; sns.set()



np.random.seed(0)
points = np.vstack(((np.random.randn(150, 2) * 0.75 + np.array([1, 0])),
                  (np.random.randn(20, 2) * 0.25 + np.array([-0.5, 0.5])),
                  (np.random.randn(20, 2) * 0.5 + np.array([-0.5, -0.5]))))
def initialize_centroids(points, k):
    """returns k centroids from the initial points"""
    centroids = points.copy()
    np.random.shuffle(centroids)
    return centroids[:k]


def closest_centroid(points, centroids):
    """returns an array containing the index to the nearest centroid for each point"""
    p=100
    distances=np.power(((np.absolute(points - centroids[:, np.newaxis]))**p).sum(axis=2),1/p)
    
    
    return np.argmin(distances, axis=0)
   
    
def move_centroids(points, closest, centroids):
    """returns the new centroids assigned from the points closest to them"""
    return np.array([points[closest==k].mean(axis=0) for k in range(centroids.shape[0])])

fig = plt.figure()
ax = plt.axes(xlim=(-4, 4), ylim=(-4, 4))
centroids = initialize_centroids(points, 3)
def init():
    return

def animate(i):
    global centroids
    
    closest = closest_centroid(points, centroids)
    centroids = move_centroids(points, closest, centroids)
 
    ax.cla()
    
    for k in range(len(centroids)):
        ss=1/(k+1)
        ax.scatter(points[closest==k][:,0], points[closest==k][:, 1], s=100)
       
    ax.scatter(centroids[:, 0], centroids[:, 1], c='r', s=100)
    return 



for k in range(2):
    animate(k)
